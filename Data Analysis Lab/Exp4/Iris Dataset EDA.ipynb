# %% [markdown]
# ## Iris Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
iris=pd.read_csv('Iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
print("**** Statistical Description for 'SepalLengthCm' column of each species ****\n")
print(iris.groupby("Species")['SepalLengthCm'].describe())
# Out:
# **** Statistical Description for 'SepalLengthCm' column of each species ****
#
#                  count   mean       std  min    25%  50%  75%  max
# Species
# Iris-setosa       50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor   50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica    50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9

# %%
print("**** Statistical Description for 'SepalWidthCm' column of each species ****\n")
print(iris.groupby("Species")['SepalWidthCm'].describe())
# Out:
# **** Statistical Description for 'SepalWidthCm' column of each species ****
#
#                  count   mean       std  min    25%  50%    75%  max
# Species
# Iris-setosa       50.0  3.418  0.381024  2.3  3.125  3.4  3.675  4.4
# Iris-versicolor   50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
# Iris-virginica    50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8

# %%
print("**** Statistical Description for 'PetalLengthCm' column of each species ****\n")
print(iris.groupby("Species")['PetalLengthCm'].describe())
# Out:
# **** Statistical Description for 'PetalLengthCm' column of each species ****
#
#                  count   mean       std  min  25%   50%    75%  max
# Species
# Iris-setosa       50.0  1.464  0.173511  1.0  1.4  1.50  1.575  1.9
# Iris-versicolor   50.0  4.260  0.469911  3.0  4.0  4.35  4.600  5.1
# Iris-virginica    50.0  5.552  0.551895  4.5  5.1  5.55  5.875  6.9

# %%
print("**** Statistical Description for 'PetalWidthCm' column of each species ****\n")
print(iris.groupby("Species")['PetalWidthCm'].describe())
# Out:
# **** Statistical Description for 'PetalWidthCm' column of each species ****
#
#                  count   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa       50.0  0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# Iris-versicolor   50.0  1.326  0.197753  1.0  1.2  1.3  1.5  1.8
# Iris-virginica    50.0  2.026  0.274650  1.4  1.8  2.0  2.3  2.5

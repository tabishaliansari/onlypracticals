# %% [markdown]
# ## Salary Dataset

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Salary_Data.csv')
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Mean

# %%
df.groupby('Gender')[['Age', 'Years of Experience', 'Salary']].mean()
# Out:
#               Age  Years of Experience         Salary
# Gender
# Female  32.626286             7.420179  107888.998672
# Male    34.418415             8.617407  121395.697630
# Other   39.571429            16.428571  125869.857143

# %%
df.groupby('Gender').describe()
# Out:
#            Age                                                       \
#          count       mean        std   min   25%   50%    75%   max
# Gender
# Female  3013.0  32.626286   6.976178  21.0  28.0  31.0  36.00  60.0
# Male    3671.0  34.418415   7.979936  22.0  28.0  32.0  40.00  62.0
# Other     14.0  39.571429  13.380320  23.0  26.5  37.0  53.75  54.0
#
#        Years of Experience             ...              Salary                 \
#                      count       mean  ...   75%   max   count           mean
# Gender                                 ...
# Female              3013.0   7.420179  ...  11.0  34.0  3013.0  107888.998672
# Male                3671.0   8.617407  ...  13.0  32.0  3671.0  121395.697630
# Other                 14.0  16.428571  ...  29.0  31.0    14.0  125869.857143
#
#
#                  std      min       25%       50%        75%       max
# Gender
# Female  52723.610035    500.0  60000.00  105000.0  150000.00  220000.0
# ...

# %% [markdown]
# ### Median

# %%
df.groupby('Age')[['Years of Experience', 'Salary']].median()
# Out:
#       Years of Experience    Salary
# Age
# 21.0                  0.0   25000.0
# 22.0                  0.0   25000.0
# 23.0                  1.0   50000.0
# 24.0                  1.0   48132.5
# 25.0                  1.0   60000.0
# 26.0                  2.0   55000.0
# 27.0                  3.0   70000.0
# 28.0                  3.0   70000.0
# 29.0                  4.0   75000.0
# 30.0                  5.0   95000.0
# 31.0                  6.0  120000.0
# 32.0                  7.0  120000.0
# 33.0                  8.0  123520.5
# 34.0                  9.0  140000.0
# 35.0                  9.0  120000.0
# 36.0                 11.0  139413.0
# 37.0                 11.0  150000.0
# 38.0                 11.0  136449.0
# 39.0                 12.0  145000.0
# 40.0                 12.5  150000.0
# 41.0                 13.0  151315.0
# 42.0                 14.0  170000.0
# 43.0                 15.0  162000.0
# 44.0                 15.0  162037.5
# 45.0                 16.0  180000.0
# ...

# %%
df.groupby('Education Level').min()
# Out:
#                     Age  Gender              Job Title  Years of Experience  \
# Education Level
# Bachelor's         23.0  Female        Account Manager                  0.0
# Bachelor's Degree  22.0  Female     Back end Developer                  0.0
# High School        21.0  Female     Back end Developer                  0.0
# Master's           25.0  Female       Business Analyst                  1.0
# Master's Degree    24.0  Female     Back end Developer                  0.0
# PhD                23.0  Female     Chief Data Officer                  0.0
# phD                27.0    Male  Marketing Coordinator                  7.0
#
#                      Salary
# Education Level
# Bachelor's            350.0
# Bachelor's Degree     500.0
# High School         25000.0
# Master's            40000.0
# Master's Degree     32000.0
# PhD                   579.0
# phD                120000.0

# %%
df.groupby('Education Level').max()
# Out:
#                     Age Gender                  Job Title  \
# Education Level
# Bachelor's         51.0   Male              Web Developer
# Bachelor's Degree  55.0   Male              Web Developer
# High School        54.0  Other              Web Developer
# Master's           53.0   Male           VP of Operations
# Master's Degree    58.0  Other              Web Developer
# PhD                62.0   Male  Software Engineer Manager
# phD                27.0   Male      Marketing Coordinator
#
#                    Years of Experience    Salary
# Education Level
# Bachelor's                        25.0  250000.0
# Bachelor's Degree                 30.0  250000.0
# High School                       31.0  166109.0
# Master's                          25.0  200000.0
# Master's Degree                   33.0  228000.0
# PhD                               34.0  250000.0
# phD                                7.0  120000.0

# %%
df.groupby('Gender')['Salary'].min()
# Out:
# Gender
# Female      500.0
# Male        350.0
# Other     62852.0
# Name: Salary, dtype: float64

# %%
df.groupby('Gender')['Salary'].max()
# Out:
# Gender
# Female    220000.0
# Male      250000.0
# Other     166109.0
# Name: Salary, dtype: float64

# %% [markdown]
# ### Standard Deviation

# %%
df.groupby('Gender')[['Age', 'Years of Experience', 'Salary']].std()
# Out:
#               Age  Years of Experience        Salary
# Gender
# Female   6.976178             5.844006  52723.610035
# Male     7.979936             6.125502  52098.626225
# Other   13.380320            12.537417  44242.382776

# %%
df.groupby('Education Level')[['Age', 'Years of Experience', 'Salary']].std()
# Out:
#                         Age  Years of Experience        Salary
# Education Level
# Bachelor's         4.816591             3.719964  46697.558848
# Bachelor's Degree  5.240928             4.596495  38387.390981
# High School        4.646225             4.067874  22549.129999
# Master's           6.794873             5.400661  39864.267750
# Master's Degree    6.334254             5.309591  38732.484980
# PhD                7.892412             5.270192  34330.096351
# phD                     NaN                  NaN           NaN

# %% [markdown]
# # Alcohol Dataset

# %% [markdown]
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv")
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.groupby('continent').sum()  # it shows all servings as per contient
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  3258              866            862
# AS                  1630             2677            399
# EU                  8720             5965           6400
# OC                  1435              935            570
# SA                  2101             1377            749
#
#            total_litres_of_pure_alcohol
# continent
# AF                                159.4
# AS                                 95.5
# EU                                387.8
# OC                                 54.1
# SA                                 75.7

# %%
drinks.groupby('continent').beer_servings  # we need record of only beer_servings so add it

# %%
drinks.groupby('continent').beer_servings.mean()   # take a mean
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
drinks.groupby('continent').sum()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  3258              866            862
# AS                  1630             2677            399
# EU                  8720             5965           6400
# OC                  1435              935            570
# SA                  2101             1377            749
#
#            total_litres_of_pure_alcohol
# continent
# AF                                159.4
# AS                                 95.5
# EU                                387.8
# OC                                 54.1
# SA                                 75.7

# %%
drinks.groupby('continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
drinks.groupby('continent').mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
drinks.groupby('continent').median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %% [markdown]
# ### Step 8. Find out (list) the names of countries which shows no cosumption of any kind of drink

# %%
opt= drinks[drinks['total_litres_of_pure_alcohol']== 0]['country']
opt
opt.tolist()
# Out:
# ['Afghanistan',
#  'Bangladesh',
#  'North Korea',
#  'Iran',
#  'Kuwait',
#  'Libya',
#  'Maldives',
#  'Marshall Islands',
#  'Mauritania',
#  'Monaco',
#  'Pakistan',
#  'San Marino',
#  'Somalia']

# %% [markdown]
# ### Step 9. Find out (list) the names of countries which has more wine_servings than beer_servings from Europe

# %%
drinks[(drinks['wine_servings']>drinks['beer_servings']) & (drinks['continent'] == 'EU')]['country']
# Out:
# 3          Andorra
# 42         Croatia
# 48         Denmark
# 61          France
# 64         Georgia
# 67          Greece
# 83           Italy
# 99      Luxembourg
# 113     Montenegro
# 136       Portugal
# 156       Slovenia
# 165         Sweden
# 166    Switzerland
# Name: country, dtype: object

# %% [markdown]
# ### Step 10. Find out (list) the names of countries from Asia which has more beer consumption than avg beer_consumption of Europe

# %%
b1 = drinks[(drinks['continent'] == 'EU') & (drinks['beer_servings'])].mean()
b1
# Out:
# C:\Users\91772\AppData\Local\Temp/ipykernel_21340/178277004.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   b1 = drinks[(drinks['continent'] == 'EU') & (drinks['beer_servings'])].mean()
# beer_servings                   206.000000
# spirit_servings                 132.538462
# wine_servings                   142.538462
# total_litres_of_pure_alcohol      8.773077
# dtype: float64

# %%
drinks[(drinks['beer_servings'] > b1['beer_servings'] ) & (drinks['continent']=='AS')]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 141  Russian Federation            247              326             73
#
#      total_litres_of_pure_alcohol continent
# 141                          11.5        AS

# %%
#Thank you

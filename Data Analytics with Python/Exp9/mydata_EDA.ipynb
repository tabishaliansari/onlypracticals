# %% [markdown]
# ## Regression Analysis EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('mydata.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Exp     50 non-null     int64
#  1   Age     50 non-null     int64
#  2   Salary  50 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 1.3 KB

# %% [markdown]
# ### Basic EDA

# %%
print(df.head())
# Out:
#    Exp  Age        Salary
# 0   11   34  196802.50720
# 1    2   32   61401.99245
# 2    3   20   74001.96603
# 3    3   34   76802.38595
# 4   12   25  210001.59060

# %%
print(df.describe())
# Out:
#              Exp        Age         Salary
# count  50.000000  50.000000      50.000000
# mean    7.580000  29.920000  144686.463919
# std     4.356979   7.425384   65364.107380
# min     0.000000  20.000000   29401.689280
# 25%     3.250000  24.000000   79852.260992
# 50%     8.000000  29.000000  151202.458200
# 75%    11.000000  35.750000  197102.366125
# max    14.000000  44.000000  243800.464100

# %%
print(df.isnull().sum())
# Out:
# Exp       0
# Age       0
# Salary    0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# Exp         int64
# Age         int64
# Salary    float64
# dtype: object

# %%
plt.figure(figsize=(8, 6))  
colors = ['indigo', 'cyan', 'lightgreen']
for i, column in enumerate(df.columns):
    plt.subplot(2, 2, i+1)
    plt.hist(df[column], bins=20, color=colors[i], edgecolor='black')
    plt.title(column) 
    plt.xlabel('Value') 
    plt.ylabel('Frequency') 
    plt.grid(True)  

plt.tight_layout()
plt.show()

# %%
print(df.corr())
# Out:
#              Exp       Age    Salary
# Exp     1.000000 -0.004845  0.999742
# Age    -0.004845  1.000000  0.017878
# Salary  0.999742  0.017878  1.000000

# %% [markdown]
# ### Regression Analysis

# %%
X = np.array(df['Exp']).reshape(-1, 1)
y = np.array(df['Salary']).reshape(-1, 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)
regr = LinearRegression()
regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.9994180345049924

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test, y_test, color ='b')
plt.plot(X_test, y_pred, color ='k')
plt.xlabel("Experience", fontsize = 20)
plt.ylabel("Salary", fontsize = 20)
plt.show()

# %%
X = np.array(df['Age']).reshape(-1, 1)
y = np.array(df['Salary']).reshape(-1, 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)
regr = LinearRegression()
regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# -0.05051113157384157

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test, y_test, color ='b')
plt.plot(X_test, y_pred, color ='k')
plt.xlabel("Age", fontsize = 20)
plt.ylabel("Salary", fontsize = 20)
plt.show()

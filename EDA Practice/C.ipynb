# %%
#importing the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing data from csv file in to a pandas dataframe
df = pd.read_csv(r"D:\AISSMS IOIT - AI&DS (628299510)\SE_2023-2024\even_sem\ESE - Target 10 sgpa\DAP 22-05-2024\kmeans.csv")
df.head()
# Out:
#    Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0      1         87073            100000                   2
# 1      2         38414             50000                   3
# 2      3         17341             50000                   7
# 3      4         40496             30000                   5
# 4      5         47437            100000                   6
#
#    Total_visits_bank  Total_visits_online  Total_calls_made
# 0                  1                    1                 0
# 1                  0                   10                 9
# 2                  1                    3                 4
# 3                  1                    1                 4
# 4                  0                   12                 3

# %%
df.columns
# Out:
# Index(['Sl_No', 'Customer Key', 'Avg_Credit_Limit', 'Total_Credit_Cards',
#        'Total_visits_bank', 'Total_visits_online', 'Total_calls_made'],
#       dtype='object')

# %%
import pandas as pd
import plotly.express as px

# Sample dataframe
"""
data = {
    'Sl_No': [1, 2, 3, 4, 5],
    'Customer Key': [101, 102, 103, 104, 105],
    'Avg_Credit_Limit': [5000, 6000, 7000, 8000, 9000],
    'Total_Credit_Cards': [2, 3, 4, 2, 3],
    'Total_visits_bank': [5, 3, 6, 2, 4],
    'Total_visits_online': [7, 8, 5, 6, 7],
    'Total_calls_made': [4, 5, 6, 3, 2]
}
"""
#df = pd.DataFrame(data)

# Creating the sunburst chart
fig = px.sunburst(
    df,
    path=['Customer Key', 'Total_Credit_Cards'],
    values='Avg_Credit_Limit',
    color='Avg_Credit_Limit',
    hover_data=['Total_visits_bank', 'Total_visits_online', 'Total_calls_made']
)

fig.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

sns.histplot(df['Avg_Credit_Limit'], kde=True, ax=axes[0, 0]).set_title('Avg Credit Limit')
sns.histplot(df['Total_Credit_Cards'], kde=True, ax=axes[0, 1]).set_title('Total Credit Cards')
sns.histplot(df['Total_visits_bank'], kde=True, ax=axes[0, 2]).set_title('Total Visits Bank')
sns.histplot(df['Total_visits_online'], kde=True, ax=axes[1, 0]).set_title('Total Visits Online')
sns.histplot(df['Total_calls_made'], kde=True, ax=axes[1, 1]).set_title('Total Calls Made')

# Remove the empty subplot
fig.delaxes(axes[1, 2])

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

sns.kdeplot(df['Avg_Credit_Limit'], ax=axes[0, 0]).set_title('Avg Credit Limit')
sns.kdeplot(df['Total_Credit_Cards'], ax=axes[0, 1]).set_title('Total Credit Cards')
sns.kdeplot(df['Total_visits_bank'], ax=axes[0, 2]).set_title('Total Visits Bank')
sns.kdeplot(df['Total_visits_online'], ax=axes[1, 0]).set_title('Total Visits Online')
sns.kdeplot(df['Total_calls_made'], ax=axes[1, 1]).set_title('Total Calls Made')

# Remove the empty subplot
fig.delaxes(axes[1, 2])

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

sns.histplot(df['Avg_Credit_Limit'], ax=axes[0, 0]).set_title('Avg Credit Limit')
sns.histplot(df['Total_Credit_Cards'], ax=axes[0, 1]).set_title('Total Credit Cards')
sns.histplot(df['Total_visits_bank'], ax=axes[0, 2]).set_title('Total Visits Bank')
sns.histplot(df['Total_visits_online'], ax=axes[1, 0]).set_title('Total Visits Online')
sns.histplot(df['Total_calls_made'], ax=axes[1, 1]).set_title('Total Calls Made')

# Remove the empty subplot
fig.delaxes(axes[1, 2])

plt.tight_layout()
plt.show()

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
#data preparation
X = np.array(df["Total_Credit_Cards"]).reshape(-1, 1)
y = np.array(df["Avg_Credit_Limit"]).reshape(-1, 1)
#train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)
#model building
regression = LinearRegression()
#model training
regression.fit(X_train, y_train)
#model evaluation
print(regression.score(X_test, y_test))
# Out:
# 0.2175531375923111

# %%
#line of best fit
y_pred = regression.predict(X_test)
plt.scatter(X_test, y_test, color = "g")
plt.plot(X_test, y_pred, color = "r")
plt.xlabel("Experience", fontsize = 15)
plt.ylabel("Salary", fontsize = 15)
plt.show()
